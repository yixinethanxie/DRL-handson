# %% [markdown]
# ## FrozenLake

# %%
from torch import nn
from torch import optim
import torch
from collections import namedtuple
import numpy as np
from tensorboardX import SummaryWriter
import gym

# Register a nonslippery frozen-lake

from gym.envs.registration import register
register(
    id='FrozenLakeNotSlippery-v0',
    entry_point='gym.envs.toy_text:FrozenLakeEnv',
    kwargs={'map_name' : '4x4', 'is_slippery': False},
    max_episode_steps=100,
    reward_threshold=0.78, # optimum = .8196
)

# %%
# Constants
HIDDEN_SIZE=128
BATCH_SIZE=100
PERCENTILE=30
GAMMA=0.9


# NN: a simple DNN with one hidden layer
class Net(nn.Module):
    def __init__(self,obs_size,hidden_size,n_actions):
        super(Net,self).__init__()
        self.pipe=nn.Sequential(
            nn.Linear(obs_size,hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size,n_actions)
        )
    def forward(self,x):
        return self.pipe(x)

# %%
Episode=namedtuple("Episode",field_names=["reward","steps"])
EpisodeStep=namedtuple('EpisodeStep',field_names=["observation","action"])

def iterate_batches(env,net,batch_size):
    batch=[]
    episode_reward=0.
    episode_steps=[]
    obs=env.reset()
    sm=nn.Softmax(dim=1)
    
    while True:
        obs_v=torch.FloatTensor([obs]) # turn obs into 2-dimensional with 1xn (from 1-dimensional with n)
        act_probs_v=sm(net(obs_v)) # apply softmax function to the output of NN, so that the outputs become probabilitiy of each action
        act_probs=act_probs_v.data.numpy()[0] # convert tensor to numpy array and reduce dimension from 2 to 1
        # randomly select action based on the probability from softmax function
        # NOTE: instead of using np.argmax to deterministicly select an action, 
        #       using random.choice introduces proper randomness and help exploration
        action=np.random.choice(len(act_probs),p=act_probs) 
        next_obs, reward,is_done,_=env.step(action)
        
        episode_reward+=reward # accumulate reward for every step
        episode_steps.append(EpisodeStep(observation=obs,action=action))
        
        if is_done:
            batch.append(Episode(reward=episode_reward, steps=episode_steps))
            episode_reward=0.
            episode_steps=[]
            next_obs=env.reset()
            if len(batch)==batch_size:
                yield batch
                batch.clear()
        
        obs=next_obs

# %%
def filter_batch(batch,percentile):
    disc_rewards=list(map(lambda s:s.reward*(GAMMA**len(s.steps)),batch)) # use GAMMA as discount factor, shorter is better
    reward_bound=np.percentile(disc_rewards,percentile) # calculate percentile of episode's total rewards as cutoff bound
    
    train_obs=[]
    train_act=[]
    elite_batch=[]
    
    for example,discounted_reward in zip(batch,disc_rewards):
        if discounted_reward>reward_bound:
            train_obs.extend(map(lambda step:step.observation, example.steps))
            train_act.extend(map(lambda step:step.action, example.steps))
            elite_batch.append(example)
    return elite_batch,train_obs,train_act,reward_bound

# %%
class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space, gym.spaces.Discrete)
        self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation]=1.0
        return res

# %%
# slippery frozen lake env
env=DiscreteOneHotWrapper(gym.make("FrozenLakeNotSlippery-v0"))

env=gym.wrappers.Monitor(env,directory="mon_fl",force=True)
obs_size=env.observation_space.shape[0]
n_actions=env.action_space.n
net=Net(obs_size,HIDDEN_SIZE,n_actions)

objective=nn.CrossEntropyLoss()
optimizer=optim.Adam(params=net.parameters(),lr=0.001)
writer=SummaryWriter(comment="-nonslippery")

full_batch=[]

for iter_no, batch in enumerate(iterate_batches(env,net,BATCH_SIZE)):
    reward_m=float(np.mean(list(map(lambda s:s.reward,batch))))
    full_batch,obs,acts,reward_b=filter_batch(full_batch+batch,PERCENTILE)
    if not full_batch:
        continue
    obs_v=torch.FloatTensor(obs)
    acts_v=torch.LongTensor(acts)
    full_batch=full_batch[-500:]
    
    optimizer.zero_grad()
    action_scores_v=net(obs_v)
    loss_v=objective(action_scores_v,acts_v)
    loss_v.backward()
    optimizer.step()
    
    print(f"{iter_no}: loss={round(loss_v.item(),3)}, reward_mean={round(reward_m,1)}, reward_bound={round(reward_b,1)}")
    writer.add_scalar("loss", loss_v.item(), iter_no)
    writer.add_scalar("reward_bound", reward_b, iter_no)
    writer.add_scalar("reward_mean", reward_m, iter_no)
    
    if reward_m>0.8:
        print("Solved!")
        break
writer.close()
# Out:
# 0: loss=1.404, reward_mean=0.0, reward_bound=0.0
# 1: loss=1.386, reward_mean=0.0, reward_bound=0.0
# 2: loss=1.382, reward_mean=0.0, reward_bound=0.0
# 3: loss=1.376, reward_mean=0.0, reward_bound=0.0
# 4: loss=1.372, reward_mean=0.0, reward_bound=0.0
# 5: loss=1.365, reward_mean=0.0, reward_bound=0.0
# 6: loss=1.364, reward_mean=0.0, reward_bound=0.0
# 7: loss=1.36, reward_mean=0.0, reward_bound=0.0
# 8: loss=1.359, reward_mean=0.0, reward_bound=0.0
# 9: loss=1.355, reward_mean=0.0, reward_bound=0.0
# 10: loss=1.354, reward_mean=0.0, reward_bound=0.0
# 11: loss=1.349, reward_mean=0.0, reward_bound=0.0
# 12: loss=1.343, reward_mean=0.0, reward_bound=0.0
# 13: loss=1.342, reward_mean=0.0, reward_bound=0.0
# 14: loss=1.338, reward_mean=0.0, reward_bound=0.0
# 15: loss=1.345, reward_mean=0.0, reward_bound=0.0
# 16: loss=1.345, reward_mean=0.1, reward_bound=0.0
# 17: loss=1.341, reward_mean=0.0, reward_bound=0.0
# 18: loss=1.332, reward_mean=0.1, reward_bound=0.0
# 19: loss=1.326, reward_mean=0.0, reward_bound=0.0
# 20: loss=1.321, reward_mean=0.0, reward_bound=0.0
# 21: loss=1.317, reward_mean=0.0, reward_bound=0.0
# 22: loss=1.313, reward_mean=0.0, reward_bound=0.0
# 23: loss=1.308, reward_mean=0.0, reward_bound=0.0
# 24: loss=1.305, reward_mean=0.0, reward_bound=0.0
# 25: loss=1.301, reward_mean=0.0, reward_bound=0.0
# 26: loss=1.297, reward_mean=0.1, reward_bound=0.0
# 27: loss=1.294, reward_mean=0.1, reward_bound=0.0
# 28: loss=1.29, reward_mean=0.0, reward_bound=0.0
# 29: loss=1.286, reward_mean=0.0, reward_bound=0.0
# 30: loss=1.282, reward_mean=0.1, reward_bound=0.0
# 31: loss=1.28, reward_mean=0.1, reward_bound=0.0
# 32: loss=1.278, reward_mean=0.1, reward_bound=0.0
# 33: loss=1.276, reward_mean=0.1, reward_bound=0.0
# 34: loss=1.27, reward_mean=0.0, reward_bound=0.0
# 35: loss=1.266, reward_mean=0.1, reward_bound=0.0
# 36: loss=1.263, reward_mean=0.0, reward_bound=0.0
# 37: loss=1.26, reward_mean=0.1, reward_bound=0.0
# 38: loss=1.256, reward_mean=0.1, reward_bound=0.0
# 39: loss=1.254, reward_mean=0.1, reward_bound=0.0
# 40: loss=1.249, reward_mean=0.1, reward_bound=0.0
# 41: loss=1.245, reward_mean=0.1, reward_bound=0.0
# 42: loss=1.24, reward_mean=0.0, reward_bound=0.0
# 43: loss=1.233, reward_mean=0.1, reward_bound=0.0
# 44: loss=1.229, reward_mean=0.1, reward_bound=0.0
# 45: loss=1.224, reward_mean=0.1, reward_bound=0.0
# 46: loss=1.219, reward_mean=0.1, reward_bound=0.0
# 47: loss=1.216, reward_mean=0.1, reward_bound=0.0
# 48: loss=1.211, reward_mean=0.1, reward_bound=0.0
# 49: loss=1.208, reward_mean=0.1, reward_bound=0.0
# 50: loss=1.194, reward_mean=0.1, reward_bound=0.1
# 51: loss=1.185, reward_mean=0.1, reward_bound=0.1
# 52: loss=1.166, reward_mean=0.1, reward_bound=0.1
# 53: loss=1.141, reward_mean=0.2, reward_bound=0.2
# 54: loss=1.138, reward_mean=0.1, reward_bound=0.2
# 55: loss=1.133, reward_mean=0.1, reward_bound=0.2
# 56: loss=1.13, reward_mean=0.1, reward_bound=0.2
# 57: loss=1.096, reward_mean=0.1, reward_bound=0.2
# 58: loss=1.08, reward_mean=0.1, reward_bound=0.3
# 59: loss=1.056, reward_mean=0.1, reward_bound=0.3
# 60: loss=1.03, reward_mean=0.1, reward_bound=0.3
# 61: loss=0.991, reward_mean=0.2, reward_bound=0.3
# 62: loss=0.994, reward_mean=0.1, reward_bound=0.0
# 63: loss=0.984, reward_mean=0.2, reward_bound=0.2
# 64: loss=0.975, reward_mean=0.2, reward_bound=0.2
# 65: loss=0.959, reward_mean=0.2, reward_bound=0.3
# 66: loss=0.903, reward_mean=0.2, reward_bound=0.4
# 67: loss=0.914, reward_mean=0.2, reward_bound=0.2
# 68: loss=0.912, reward_mean=0.2, reward_bound=0.2
# 69: loss=0.891, reward_mean=0.2, reward_bound=0.3
# 70: loss=0.873, reward_mean=0.2, reward_bound=0.3
# 71: loss=0.853, reward_mean=0.2, reward_bound=0.4
# 72: loss=0.782, reward_mean=0.2, reward_bound=0.4
# 73: loss=0.805, reward_mean=0.2, reward_bound=0.0
# 74: loss=0.821, reward_mean=0.2, reward_bound=0.0
# 75: loss=0.799, reward_mean=0.3, reward_bound=0.3
# 76: loss=0.769, reward_mean=0.3, reward_bound=0.3
# 77: loss=0.741, reward_mean=0.3, reward_bound=0.4
# 78: loss=0.712, reward_mean=0.3, reward_bound=0.4
# 79: loss=0.607, reward_mean=0.4, reward_bound=0.5
# 80: loss=0.678, reward_mean=0.3, reward_bound=0.0
# 81: loss=0.639, reward_mean=0.4, reward_bound=0.3
# 82: loss=0.618, reward_mean=0.3, reward_bound=0.4
# 83: loss=0.566, reward_mean=0.3, reward_bound=0.4
# 84: loss=0.558, reward_mean=0.3, reward_bound=0.5
# 85: loss=0.519, reward_mean=0.4, reward_bound=0.5
# 86: loss=0.51, reward_mean=0.4, reward_bound=0.4
# 87: loss=0.508, reward_mean=0.4, reward_bound=0.5
# 88: loss=0.477, reward_mean=0.4, reward_bound=0.5
# 90: loss=0.705, reward_mean=0.4, reward_bound=0.0
# 91: loss=0.714, reward_mean=0.4, reward_bound=0.0
# 92: loss=0.703, reward_mean=0.5, reward_bound=0.2
# 93: loss=0.639, reward_mean=0.5, reward_bound=0.3
# 94: loss=0.556, reward_mean=0.5, reward_bound=0.4
# 95: loss=0.496, reward_mean=0.5, reward_bound=0.4
# 96: loss=0.401, reward_mean=0.5, reward_bound=0.5
# 97: loss=0.394, reward_mean=0.5, reward_bound=0.5
# 99: loss=0.621, reward_mean=0.5, reward_bound=0.0
# 100: loss=0.61, reward_mean=0.5, reward_bound=0.0
# 101: loss=0.53, reward_mean=0.5, reward_bound=0.3
# 102: loss=0.439, reward_mean=0.7, reward_bound=0.4
# 103: loss=0.432, reward_mean=0.6, reward_bound=0.5
# 104: loss=0.359, reward_mean=0.6, reward_bound=0.5
# 106: loss=0.537, reward_mean=0.6, reward_bound=0.0
# 107: loss=0.393, reward_mean=0.7, reward_bound=0.4
# 108: loss=0.316, reward_mean=0.6, reward_bound=0.5
# 110: loss=0.601, reward_mean=0.6, reward_bound=0.0
# 111: loss=0.382, reward_mean=0.7, reward_bound=0.4
# 112: loss=0.294, reward_mean=0.7, reward_bound=0.5
# 113: loss=0.295, reward_mean=0.7, reward_bound=0.5
# 115: loss=0.438, reward_mean=0.6, reward_bound=0.0
# 116: loss=0.384, reward_mean=0.7, reward_bound=0.4
# 117: loss=0.285, reward_mean=0.7, reward_bound=0.5
# 119: loss=0.528, reward_mean=0.6, reward_bound=0.0
# 120: loss=0.346, reward_mean=0.7, reward_bound=0.4
# 121: loss=0.257, reward_mean=0.7, reward_bound=0.5
# 122: loss=0.265, reward_mean=0.7, reward_bound=0.5
# 124: loss=0.333, reward_mean=0.8, reward_bound=0.4
# Solved!
