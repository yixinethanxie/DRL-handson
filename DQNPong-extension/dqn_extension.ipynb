# %%
from torch import nn
import torch
import torch.nn.functional as F
import gym
import torch.optim as optim
from tensorboardX import SummaryWriter
from lib import common,dqn_model
import ptan
import numpy as np

# n-step
REWARD_STEPS=2

# priority replay
PRIO_REPLAY_ALPHA=0.6
BETA_START=0.4
BETA_FRAMES=100000

# C51
Vmax=10
Vmin=-10
N_ATOMS=51
DELTA_Z=(Vmax-Vmin)/(N_ATOMS-1)

class RainbowDQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(RainbowDQN,self).__init__()
        
        self.conv=nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32,64,kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64,64,kernel_size=3, stride=1),
            nn.ReLU()
        )
        
        conv_out_size=self._get_conv_out(input_shape)
        self.fc_val=nn.Sequential(
            dqn_model.NoisyLinear(conv_out_size, 512),
            nn.ReLU(),
            dqn_model.NoisyLinear(512,N_ATOMS)
        )
        
        self.fc_adv=nn.Sequential(
            dqn_model.NoisyLinear(conv_out_size, 512),
            nn.ReLU(),
            dqn_model.NoisyLinear(512,n_actions*N_ATOMS)
        )
        
        self.register_buffer("supports", 
                             torch.arange(Vmin, Vmax+DELTA_Z,DELTA_Z))
        self.softmax=nn.Softmax(dim=1)
        
    def _get_conv_out(self,shape):
        o=self.conv(torch.zeros(1,*shape))
        return int(np.prod(o.size()))
    
    def forward(self,x):
        batch_size=x.size()[0]
        fx=x.float()/256
        conv_out=self.conv(fx).view(batch_size,-1)
        val_out=self.fc_val(conv_out).view(batch_size,1,N_ATOMS)
        adv_out=self.fc_adv(conv_out).view(batch_size,-1,N_ATOMS)
        adv_mean=adv_out.mean(dim=1,keepdim=True)
        return val_out+adv_out-adv_mean
    
    def both(self,x):
        cat_out=self(x)
        probs=self.apply_softmax(cat_out)
        weights=probs*self.supports
        res=weights.sum(dim=2)
        return cat_out,res
    
    def qvals(self,x):
        return self.both(x)[1]
    
    def apply_softmax(self,t):
        return self.softmax(t.view(-1,N_ATOMS)).view(t.size())
    
def calc_loss(batch, batch_weights, net, tgt_net, gamma, device="cpu"):
    states, actions, rewards,dones, next_states=\
        common.unpack_batch(batch)
    batch_size=len(batch)
    
    states_v=torch.tensor(states).to(device)
    actions_v=torch.tensor(actions).to(device)
    next_states_v=torch.tensor(next_states).to(device)
    batch_weights_v=torch.tensor(batch_weights).to(device)
    
    distr_v,qvals_v=net.both(torch.cat((states_v, next_states_v)))
    next_qvals_v=qvals_v[batch_size:]
    distr_v=distr_v[:batch_size]
    
    next_actions_v=next_qvals_v.max(1)[1]
    next_distr_v=tgt_net(next_states_v)
    next_best_distr_v=next_distr_v[range(batch_size),next_actions_v.data]
    next_best_distr_v=tgt_net.apply_softmax(next_best_distr_v)
    next_best_distr=next_best_distr_v.data.cpu().numpy()
    
    dones=dones.astype(np.bool)
    proj_distr=common.distr_projection(next_best_distr,rewards,
                                      dones,Vmin,Vmax,N_ATOMS,gamma)
    
    state_action_values=distr_v[range(batch_size),actions_v.data]
    state_log_sm_v=F.log_softmax(state_action_values,dim=1)
    proj_distr_v=torch.tensor(proj_distr).to(device)
    
    loss_v=-state_log_sm_v*proj_distr_v
    loss_v=batch_weights_v*loss_v.sum(dim=1)
    return loss_v.mean(), loss_v+1e-5

# %%
params=common.HYPERPARAMS['pong']
device=torch.device("cuda")
env=gym.make(params["env_name"])
env=ptan.common.wrappers.wrap_dqn(env)

writer=SummaryWriter(comment="-"+params["run_name"]+"-rainbow")
net=RainbowDQN(env.observation_space.shape, env.action_space.n).to(device)
tgt_net=ptan.agent.TargetNet(net)
agent=ptan.agent.DQNAgent(lambda x:net.qvals(x),
                         ptan.actions.ArgmaxActionSelector(),
                         device=device)

exp_source=\
    ptan.experience.ExperienceSourceFirstLast(env,agent,
                                              gamma=params["gamma"],
                                              steps_count=REWARD_STEPS)
buffer=ptan.experience.PrioritizedReplayBuffer(exp_source,
                                               params["replay_size"],
                                               PRIO_REPLAY_ALPHA)
optimizer=optim.Adam(net.parameters(),
                     lr=params["learning_rate"])


frame_idx=0
beta=BETA_START

with common.RewardTracker(writer,params["stop_reward"]) as reward_tracker:
    while True:
        frame_idx += 1
        buffer.populate(1)
        beta=min(1.0, BETA_START+frame_idx*(1.0-BETA_START)/BETA_FRAMES)
        
        new_rewards=exp_source.pop_total_rewards()
        if new_rewards:
            if reward_tracker.reward(new_rewards[0],frame_idx):
                break
        if len(buffer)<params["replay_initial"]:
            continue
        optimizer.zero_grad()
        batch,batch_indices,batch_weights=\
            buffer.sample(params["batch_size"],beta)
        loss_v,sample_prios_v=calc_loss(batch,batch_weights,net,
                                        tgt_net.target_model,
                                        params["gamma"]**REWARD_STEPS,
                                        device=device)
        loss_v.backward()
        optimizer.step()
        buffer.update_priorities(batch_indices,
                                sample_prios_v.data.cpu().numpy())

        if frame_idx%params["target_net_sync"]==0:
            tgt_net.sync()
# Out:
# 820: done 1 games, mean reward -21.000, speed 503.34 f/s
# 1716: done 2 games, mean reward -20.500, speed 487.10 f/s
# 2533: done 3 games, mean reward -20.667, speed 502.03 f/s
# 3356: done 4 games, mean reward -20.750, speed 493.04 f/s
# 4236: done 5 games, mean reward -20.800, speed 501.95 f/s
# 5056: done 6 games, mean reward -20.833, speed 508.88 f/s
# 5834: done 7 games, mean reward -20.857, speed 507.33 f/s
# 6656: done 8 games, mean reward -20.875, speed 504.67 f/s
# 7568: done 9 games, mean reward -20.778, speed 511.83 f/s
# 8389: done 10 games, mean reward -20.800, speed 505.01 f/s
# 9225: done 11 games, mean reward -20.818, speed 502.87 f/s
# 10042: done 12 games, mean reward -20.833, speed 378.83 f/s
# 10864: done 13 games, mean reward -20.846, speed 68.79 f/s
# 11748: done 14 games, mean reward -20.857, speed 68.61 f/s
# 12692: done 15 games, mean reward -20.867, speed 68.29 f/s
# 13650: done 16 games, mean reward -20.812, speed 68.59 f/s
# 14473: done 17 games, mean reward -20.824, speed 68.56 f/s
# 15295: done 18 games, mean reward -20.833, speed 68.33 f/s
# 16111: done 19 games, mean reward -20.842, speed 68.37 f/s
# 16931: done 20 games, mean reward -20.850, speed 68.52 f/s
# 17689: done 21 games, mean reward -20.857, speed 68.22 f/s
# 18449: done 22 games, mean reward -20.864, speed 68.23 f/s
# 19271: done 23 games, mean reward -20.870, speed 68.18 f/s
# 20030: done 24 games, mean reward -20.875, speed 67.86 f/s
# 20787: done 25 games, mean reward -20.880, speed 68.01 f/s
# 21548: done 26 games, mean reward -20.885, speed 68.36 f/s
# 22309: done 27 games, mean reward -20.889, speed 68.28 f/s
# 23068: done 28 games, mean reward -20.893, speed 66.15 f/s
# 23830: done 29 games, mean reward -20.897, speed 66.55 f/s
# 24587: done 30 games, mean reward -20.900, speed 67.53 f/s
# 25347: done 31 games, mean reward -20.903, speed 67.79 f/s
# 26103: done 32 games, mean reward -20.906, speed 67.75 f/s
# 26861: done 33 games, mean reward -20.909, speed 67.46 f/s
# 27620: done 34 games, mean reward -20.912, speed 68.16 f/s
# 28380: done 35 games, mean reward -20.914, speed 68.09 f/s
# 29138: done 36 games, mean reward -20.917, speed 68.06 f/s
# 29957: done 37 games, mean reward -20.919, speed 68.27 f/s
# 30718: done 38 games, mean reward -20.921, speed 66.55 f/s
# 31477: done 39 games, mean reward -20.923, speed 68.20 f/s
# 32236: done 40 games, mean reward -20.925, speed 66.40 f/s
# 32996: done 41 games, mean reward -20.927, speed 67.98 f/s
# 33755: done 42 games, mean reward -20.929, speed 67.59 f/s
# 34517: done 43 games, mean reward -20.930, speed 67.89 f/s
# 35274: done 44 games, mean reward -20.932, speed 68.29 f/s
# 36034: done 45 games, mean reward -20.933, speed 68.10 f/s
# 36795: done 46 games, mean reward -20.935, speed 68.15 f/s
# 37556: done 47 games, mean reward -20.936, speed 68.12 f/s
# 38317: done 48 games, mean reward -20.938, speed 68.14 f/s
# 39080: done 49 games, mean reward -20.939, speed 68.06 f/s
# 39840: done 50 games, mean reward -20.940, speed 67.23 f/s
# 40602: done 51 games, mean reward -20.941, speed 68.20 f/s
# 41360: done 52 games, mean reward -20.942, speed 68.18 f/s
# 42122: done 53 games, mean reward -20.943, speed 68.09 f/s
# 42880: done 54 games, mean reward -20.944, speed 68.13 f/s
# 43638: done 55 games, mean reward -20.945, speed 68.07 f/s
# 44395: done 56 games, mean reward -20.946, speed 67.65 f/s
# 45157: done 57 games, mean reward -20.947, speed 67.91 f/s
# 45914: done 58 games, mean reward -20.948, speed 67.73 f/s
# 46675: done 59 games, mean reward -20.949, speed 68.13 f/s
# 47555: done 60 games, mean reward -20.950, speed 68.21 f/s
# 48315: done 61 games, mean reward -20.951, speed 68.07 f/s
# 49076: done 62 games, mean reward -20.952, speed 68.13 f/s
# 49835: done 63 games, mean reward -20.952, speed 68.45 f/s
# 50596: done 64 games, mean reward -20.953, speed 68.45 f/s
# 51355: done 65 games, mean reward -20.954, speed 68.38 f/s
# 52118: done 66 games, mean reward -20.955, speed 68.19 f/s
# 52875: done 67 games, mean reward -20.955, speed 68.40 f/s
# 53637: done 68 games, mean reward -20.956, speed 68.43 f/s
# 54538: done 69 games, mean reward -20.942, speed 68.22 f/s
# 55300: done 70 games, mean reward -20.943, speed 67.94 f/s
# 56057: done 71 games, mean reward -20.944, speed 66.74 f/s
# 56818: done 72 games, mean reward -20.944, speed 68.10 f/s
# 57581: done 73 games, mean reward -20.945, speed 67.15 f/s
# 58342: done 74 games, mean reward -20.946, speed 68.05 f/s
# 59098: done 75 games, mean reward -20.947, speed 67.96 f/s
# 59856: done 76 games, mean reward -20.947, speed 68.06 f/s
# 60612: done 77 games, mean reward -20.948, speed 68.31 f/s
# 61374: done 78 games, mean reward -20.949, speed 67.39 f/s
# 62135: done 79 games, mean reward -20.949, speed 68.17 f/s
# 62894: done 80 games, mean reward -20.950, speed 68.38 f/s
# 63656: done 81 games, mean reward -20.951, speed 68.41 f/s
# 64413: done 82 games, mean reward -20.951, speed 68.24 f/s
# 65169: done 83 games, mean reward -20.952, speed 67.09 f/s
# 65930: done 84 games, mean reward -20.952, speed 67.77 f/s
# 66690: done 85 games, mean reward -20.953, speed 67.72 f/s
# 67450: done 86 games, mean reward -20.953, speed 68.40 f/s
# 68213: done 87 games, mean reward -20.954, speed 67.62 f/s
# 68976: done 88 games, mean reward -20.955, speed 67.82 f/s
# 69732: done 89 games, mean reward -20.955, speed 67.78 f/s
# 70491: done 90 games, mean reward -20.956, speed 67.67 f/s
# 71252: done 91 games, mean reward -20.956, speed 66.44 f/s
# 72014: done 92 games, mean reward -20.957, speed 66.79 f/s
# 72777: done 93 games, mean reward -20.957, speed 66.26 f/s
# 73534: done 94 games, mean reward -20.957, speed 65.64 f/s
# 74294: done 95 games, mean reward -20.958, speed 67.43 f/s
# 75051: done 96 games, mean reward -20.958, speed 66.34 f/s
# 75810: done 97 games, mean reward -20.959, speed 66.48 f/s
# 76568: done 98 games, mean reward -20.959, speed 66.76 f/s
# 77325: done 99 games, mean reward -20.960, speed 66.77 f/s
# 78087: done 100 games, mean reward -20.960, speed 67.30 f/s
# 78847: done 101 games, mean reward -20.960, speed 67.30 f/s
# 79603: done 102 games, mean reward -20.970, speed 66.20 f/s
# 80359: done 103 games, mean reward -20.970, speed 67.20 f/s
# 81118: done 104 games, mean reward -20.970, speed 66.62 f/s
# 81880: done 105 games, mean reward -20.970, speed 66.82 f/s
# 82698: done 106 games, mean reward -20.970, speed 66.67 f/s
# 83459: done 107 games, mean reward -20.970, speed 67.27 f/s
# 84215: done 108 games, mean reward -20.970, speed 67.09 f/s
# 84978: done 109 games, mean reward -20.980, speed 66.67 f/s
# 85794: done 110 games, mean reward -20.980, speed 66.54 f/s
# 86553: done 111 games, mean reward -20.980, speed 67.23 f/s
# 87310: done 112 games, mean reward -20.980, speed 66.67 f/s
# 88126: done 113 games, mean reward -20.980, speed 67.03 f/s
# 88887: done 114 games, mean reward -20.980, speed 67.02 f/s
# 89708: done 115 games, mean reward -20.980, speed 66.63 f/s
# 90464: done 116 games, mean reward -20.990, speed 66.67 f/s
# 91225: done 117 games, mean reward -20.990, speed 66.39 f/s
# 91985: done 118 games, mean reward -20.990, speed 66.34 f/s
# 92958: done 119 games, mean reward -20.980, speed 66.22 f/s
# 93776: done 120 games, mean reward -20.980, speed 66.18 f/s
# 94586: done 121 games, mean reward -20.980, speed 66.64 f/s
# 95348: done 122 games, mean reward -20.980, speed 66.66 f/s
# 96104: done 123 games, mean reward -20.980, speed 65.46 f/s
# 96891: done 124 games, mean reward -20.980, speed 66.00 f/s
# 97647: done 125 games, mean reward -20.980, speed 65.60 f/s
# 98407: done 126 games, mean reward -20.980, speed 65.55 f/s
# 99170: done 127 games, mean reward -20.980, speed 65.55 f/s
# 99929: done 128 games, mean reward -20.980, speed 67.06 f/s
# 100793: done 129 games, mean reward -20.970, speed 66.09 f/s
# 101550: done 130 games, mean reward -20.970, speed 67.10 f/s
# 102311: done 131 games, mean reward -20.970, speed 67.18 f/s
# 103086: done 132 games, mean reward -20.970, speed 67.13 f/s
# 103846: done 133 games, mean reward -20.970, speed 67.13 f/s
# 104604: done 134 games, mean reward -20.970, speed 67.00 f/s
# 105360: done 135 games, mean reward -20.970, speed 67.08 f/s
# 106118: done 136 games, mean reward -20.970, speed 66.17 f/s
# 106881: done 137 games, mean reward -20.970, speed 66.35 f/s
# 107640: done 138 games, mean reward -20.970, speed 67.01 f/s
# 108462: done 139 games, mean reward -20.970, speed 66.91 f/s
# 109219: done 140 games, mean reward -20.970, speed 66.94 f/s
# 110041: done 141 games, mean reward -20.970, speed 66.95 f/s
# 110861: done 142 games, mean reward -20.970, speed 66.55 f/s
# 111700: done 143 games, mean reward -20.960, speed 66.40 f/s
# 112577: done 144 games, mean reward -20.960, speed 66.66 f/s
# 113339: done 145 games, mean reward -20.960, speed 66.47 f/s
# 114218: done 146 games, mean reward -20.960, speed 66.64 f/s
# 114975: done 147 games, mean reward -20.960, speed 66.66 f/s
# 115732: done 148 games, mean reward -20.960, speed 66.53 f/s
# 116567: done 149 games, mean reward -20.950, speed 66.27 f/s
# 117391: done 150 games, mean reward -20.950, speed 66.24 f/s
# 118151: done 151 games, mean reward -20.950, speed 66.84 f/s
# 118973: done 152 games, mean reward -20.950, speed 66.31 f/s
# 119729: done 153 games, mean reward -20.950, speed 66.36 f/s
# 120549: done 154 games, mean reward -20.950, speed 66.05 f/s
# 121309: done 155 games, mean reward -20.950, speed 64.89 f/s
# 122156: done 156 games, mean reward -20.950, speed 66.77 f/s
# 122919: done 157 games, mean reward -20.950, speed 66.47 f/s
# 123679: done 158 games, mean reward -20.950, speed 66.93 f/s
# 124518: done 159 games, mean reward -20.940, speed 65.43 f/s
# 125324: done 160 games, mean reward -20.940, speed 66.26 f/s
# 126083: done 161 games, mean reward -20.940, speed 67.06 f/s
# 126840: done 162 games, mean reward -20.940, speed 66.13 f/s
# 127601: done 163 games, mean reward -20.940, speed 66.96 f/s
# 128358: done 164 games, mean reward -20.940, speed 66.18 f/s
# 129115: done 165 games, mean reward -20.940, speed 66.38 f/s
# 130086: done 166 games, mean reward -20.920, speed 66.70 f/s
# 131076: done 167 games, mean reward -20.910, speed 66.78 f/s
# 131837: done 168 games, mean reward -20.910, speed 66.89 f/s
# 132670: done 169 games, mean reward -20.910, speed 66.82 f/s
# 133507: done 170 games, mean reward -20.900, speed 66.61 f/s
# 134269: done 171 games, mean reward -20.900, speed 66.30 f/s
# 135105: done 172 games, mean reward -20.890, speed 66.26 f/s
# 135862: done 173 games, mean reward -20.890, speed 66.26 f/s
# 136697: done 174 games, mean reward -20.890, speed 66.52 f/s
# 137484: done 175 games, mean reward -20.890, speed 66.71 f/s
# 138241: done 176 games, mean reward -20.890, speed 66.46 f/s
# 139132: done 177 games, mean reward -20.880, speed 66.55 f/s
# 139891: done 178 games, mean reward -20.880, speed 66.51 f/s
# 140727: done 179 games, mean reward -20.870, speed 66.48 f/s
# 141486: done 180 games, mean reward -20.870, speed 66.57 f/s
# 142244: done 181 games, mean reward -20.870, speed 64.29 f/s
# 143006: done 182 games, mean reward -20.870, speed 64.58 f/s
# 143968: done 183 games, mean reward -20.860, speed 64.16 f/s
# 144752: done 184 games, mean reward -20.860, speed 64.24 f/s
# 145513: done 185 games, mean reward -20.860, speed 64.88 f/s
# 146426: done 186 games, mean reward -20.850, speed 64.95 f/s
# 147212: done 187 games, mean reward -20.850, speed 64.33 f/s
# 148031: done 188 games, mean reward -20.850, speed 64.31 f/s
# 148871: done 189 games, mean reward -20.840, speed 64.33 f/s
# 149634: done 190 games, mean reward -20.840, speed 65.67 f/s
# 150687: done 191 games, mean reward -20.810, speed 66.20 f/s
# 151449: done 192 games, mean reward -20.810, speed 66.33 f/s
# 152230: done 193 games, mean reward -20.810, speed 66.31 f/s
# 153005: done 194 games, mean reward -20.810, speed 66.20 f/s
# 153894: done 195 games, mean reward -20.800, speed 64.37 f/s
# 154650: done 196 games, mean reward -20.800, speed 66.39 f/s
# 155480: done 197 games, mean reward -20.790, speed 66.59 f/s
# 156375: done 198 games, mean reward -20.780, speed 66.60 f/s
# 157138: done 199 games, mean reward -20.780, speed 66.48 f/s
# 157896: done 200 games, mean reward -20.780, speed 66.50 f/s
# 158656: done 201 games, mean reward -20.780, speed 66.46 f/s
# 159415: done 202 games, mean reward -20.780, speed 66.55 f/s
# 160177: done 203 games, mean reward -20.780, speed 66.46 f/s
# 161018: done 204 games, mean reward -20.770, speed 66.26 f/s
# 161778: done 205 games, mean reward -20.770, speed 66.59 f/s
# 162568: done 206 games, mean reward -20.770, speed 65.85 f/s
# 163465: done 207 games, mean reward -20.760, speed 65.54 f/s
# 164309: done 208 games, mean reward -20.760, speed 66.34 f/s
# 165066: done 209 games, mean reward -20.760, speed 66.27 f/s
# 165824: done 210 games, mean reward -20.760, speed 66.57 f/s
# 166583: done 211 games, mean reward -20.760, speed 66.38 f/s
# 167484: done 212 games, mean reward -20.750, speed 65.97 f/s
# 168421: done 213 games, mean reward -20.730, speed 66.32 f/s
# 169257: done 214 games, mean reward -20.720, speed 66.41 f/s
# 170079: done 215 games, mean reward -20.720, speed 66.37 f/s
# 170976: done 216 games, mean reward -20.710, speed 66.44 f/s
# 171807: done 217 games, mean reward -20.700, speed 66.34 f/s
# 172752: done 218 games, mean reward -20.700, speed 66.51 f/s
# 173546: done 219 games, mean reward -20.710, speed 65.89 f/s
# 174394: done 220 games, mean reward -20.710, speed 66.59 f/s
# 175156: done 221 games, mean reward -20.710, speed 66.48 f/s
# 176017: done 222 games, mean reward -20.700, speed 66.55 f/s
# 176927: done 223 games, mean reward -20.690, speed 65.80 f/s
# 177803: done 224 games, mean reward -20.680, speed 66.50 f/s
# 178667: done 225 games, mean reward -20.680, speed 65.45 f/s
# 179449: done 226 games, mean reward -20.680, speed 65.25 f/s
# 180207: done 227 games, mean reward -20.680, speed 65.55 f/s
# 181069: done 228 games, mean reward -20.670, speed 65.11 f/s
# 182015: done 229 games, mean reward -20.660, speed 65.27 f/s
# 182821: done 230 games, mean reward -20.660, speed 65.15 f/s
# 183654: done 231 games, mean reward -20.650, speed 65.48 f/s
# 184434: done 232 games, mean reward -20.650, speed 65.37 f/s
# 185209: done 233 games, mean reward -20.650, speed 65.74 f/s
# 186087: done 234 games, mean reward -20.650, speed 65.59 f/s
# 186953: done 235 games, mean reward -20.640, speed 65.46 f/s
# 187739: done 236 games, mean reward -20.640, speed 65.12 f/s
# 188519: done 237 games, mean reward -20.640, speed 65.84 f/s
# 189297: done 238 games, mean reward -20.640, speed 66.03 f/s
# 190057: done 239 games, mean reward -20.640, speed 65.55 f/s
# 190836: done 240 games, mean reward -20.640, speed 65.96 f/s
# 191617: done 241 games, mean reward -20.640, speed 66.09 f/s
# 192407: done 242 games, mean reward -20.640, speed 65.74 f/s
# 193183: done 243 games, mean reward -20.650, speed 65.88 f/s
# 194013: done 244 games, mean reward -20.640, speed 64.97 f/s
# 194850: done 245 games, mean reward -20.630, speed 66.14 f/s
# 195658: done 246 games, mean reward -20.630, speed 66.39 f/s
# 196434: done 247 games, mean reward -20.630, speed 66.37 f/s
# 197275: done 248 games, mean reward -20.620, speed 66.27 f/s
# 198057: done 249 games, mean reward -20.630, speed 65.43 f/s
# 198898: done 250 games, mean reward -20.620, speed 66.22 f/s
# 199845: done 251 games, mean reward -20.610, speed 66.27 f/s
# 200626: done 252 games, mean reward -20.610, speed 66.08 f/s
# 201511: done 253 games, mean reward -20.600, speed 66.18 f/s
# 202339: done 254 games, mean reward -20.600, speed 66.22 f/s
# 203313: done 255 games, mean reward -20.590, speed 65.97 f/s
# 204516: done 256 games, mean reward -20.570, speed 66.34 f/s
# 205494: done 257 games, mean reward -20.560, speed 66.18 f/s
# 206349: done 258 games, mean reward -20.550, speed 66.26 f/s
# 207402: done 259 games, mean reward -20.550, speed 66.35 f/s
# 208477: done 260 games, mean reward -20.540, speed 66.35 f/s
# 209670: done 261 games, mean reward -20.510, speed 66.41 f/s
# 210707: done 262 games, mean reward -20.480, speed 66.26 f/s
# 211850: done 263 games, mean reward -20.440, speed 66.16 f/s
# 213071: done 264 games, mean reward -20.420, speed 66.07 f/s
# 214471: done 265 games, mean reward -20.380, speed 66.17 f/s
# 215602: done 266 games, mean reward -20.380, speed 66.18 f/s
# 217472: done 267 games, mean reward -20.290, speed 66.17 f/s
# 218975: done 268 games, mean reward -20.210, speed 66.37 f/s
# 220365: done 269 games, mean reward -20.180, speed 65.98 f/s
# 221821: done 270 games, mean reward -20.130, speed 66.30 f/s
# 223217: done 271 games, mean reward -20.130, speed 66.45 f/s
# 224439: done 272 games, mean reward -20.130, speed 66.42 f/s
# 226081: done 273 games, mean reward -20.090, speed 66.40 f/s
# 228003: done 274 games, mean reward -20.050, speed 66.45 f/s
# 229464: done 275 games, mean reward -20.050, speed 66.17 f/s
# 230843: done 276 games, mean reward -20.050, speed 66.02 f/s
# 232230: done 277 games, mean reward -20.060, speed 65.90 f/s
# 234074: done 278 games, mean reward -19.960, speed 65.95 f/s
# 235457: done 279 games, mean reward -19.970, speed 65.71 f/s
# 236922: done 280 games, mean reward -19.970, speed 66.05 f/s
# 238632: done 281 games, mean reward -19.900, speed 65.75 f/s
# 240189: done 282 games, mean reward -19.880, speed 65.99 f/s
# 241903: done 283 games, mean reward -19.810, speed 66.22 f/s
# 243319: done 284 games, mean reward -19.810, speed 66.06 f/s
# 244776: done 285 games, mean reward -19.800, speed 66.23 f/s
# 246306: done 286 games, mean reward -19.800, speed 66.37 f/s
# 247910: done 287 games, mean reward -19.800, speed 66.23 f/s
# 249420: done 288 games, mean reward -19.800, speed 66.08 f/s
# 250880: done 289 games, mean reward -19.810, speed 66.19 f/s
# 252490: done 290 games, mean reward -19.800, speed 66.37 f/s
# 254101: done 291 games, mean reward -19.810, speed 66.38 f/s
# 255705: done 292 games, mean reward -19.800, speed 66.32 f/s
# 257386: done 293 games, mean reward -19.710, speed 66.19 f/s
# 258965: done 294 games, mean reward -19.690, speed 66.24 f/s
# 260621: done 295 games, mean reward -19.680, speed 66.30 f/s
# 262759: done 296 games, mean reward -19.570, speed 65.54 f/s
# 264292: done 297 games, mean reward -19.580, speed 65.59 f/s
# 265855: done 298 games, mean reward -19.590, speed 65.41 f/s
# 267254: done 299 games, mean reward -19.590, speed 64.94 f/s
# 268791: done 300 games, mean reward -19.590, speed 65.48 f/s
# 270291: done 301 games, mean reward -19.570, speed 65.65 f/s
# 271800: done 302 games, mean reward -19.560, speed 65.77 f/s
# 273280: done 303 games, mean reward -19.550, speed 66.13 f/s
# 275640: done 304 games, mean reward -19.410, speed 66.23 f/s
# 277757: done 305 games, mean reward -19.280, speed 66.22 f/s
# 279571: done 306 games, mean reward -19.250, speed 65.70 f/s
# 281797: done 307 games, mean reward -19.130, speed 66.11 f/s
# 283537: done 308 games, mean reward -19.110, speed 66.19 f/s
# 286217: done 309 games, mean reward -18.930, speed 66.00 f/s
# 287973: done 310 games, mean reward -18.890, speed 66.01 f/s
# 289158: done 311 games, mean reward -18.880, speed 65.90 f/s
# 291007: done 312 games, mean reward -18.820, speed 65.63 f/s
# 292616: done 313 games, mean reward -18.810, speed 65.92 f/s
# 294182: done 314 games, mean reward -18.780, speed 65.70 f/s
# 296603: done 315 games, mean reward -18.650, speed 65.46 f/s
# 298689: done 316 games, mean reward -18.550, speed 65.72 f/s
# 301073: done 317 games, mean reward -18.400, speed 65.30 f/s
# 303676: done 318 games, mean reward -18.230, speed 65.91 f/s
# 305604: done 319 games, mean reward -18.140, speed 66.12 f/s
# 308323: done 320 games, mean reward -17.980, speed 66.18 f/s
# 311301: done 321 games, mean reward -17.750, speed 66.47 f/s
# 314105: done 322 games, mean reward -17.580, speed 66.00 f/s
# 316763: done 323 games, mean reward -17.340, speed 65.65 f/s
# 319574: done 324 games, mean reward -17.120, speed 65.84 f/s
# 321389: done 325 games, mean reward -17.070, speed 65.83 f/s
# 323685: done 326 games, mean reward -16.930, speed 65.98 f/s
# 326552: done 327 games, mean reward -16.730, speed 66.01 f/s
# 328996: done 328 games, mean reward -16.600, speed 65.88 f/s
# 331271: done 329 games, mean reward -16.280, speed 65.68 f/s
# 333173: done 330 games, mean reward -15.890, speed 65.57 f/s
# 335321: done 331 games, mean reward -15.560, speed 65.62 f/s
# 337087: done 332 games, mean reward -15.160, speed 65.94 f/s
# 338885: done 333 games, mean reward -14.770, speed 65.40 f/s
# 340960: done 334 games, mean reward -14.430, speed 66.20 f/s
# 342795: done 335 games, mean reward -14.050, speed 65.26 f/s
# 344545: done 336 games, mean reward -13.650, speed 65.76 f/s
# 346576: done 337 games, mean reward -13.290, speed 66.25 f/s
# 348402: done 338 games, mean reward -12.900, speed 66.16 f/s
# 350186: done 339 games, mean reward -12.500, speed 65.95 f/s
# 351820: done 340 games, mean reward -12.080, speed 66.02 f/s
# 353510: done 341 games, mean reward -11.670, speed 65.97 f/s
# 355286: done 342 games, mean reward -11.280, speed 66.09 f/s
# 356978: done 343 games, mean reward -10.870, speed 65.93 f/s
# 358675: done 344 games, mean reward -10.470, speed 65.92 f/s
# 360367: done 345 games, mean reward -10.070, speed 66.44 f/s
# 362091: done 346 games, mean reward -9.660, speed 66.45 f/s
# 363872: done 347 games, mean reward -9.270, speed 66.42 f/s
# 365565: done 348 games, mean reward -8.870, speed 66.36 f/s
# 367230: done 349 games, mean reward -8.460, speed 66.47 f/s
# 369105: done 350 games, mean reward -8.080, speed 66.39 f/s
# 370774: done 351 games, mean reward -7.680, speed 66.44 f/s
# 372403: done 352 games, mean reward -7.260, speed 66.46 f/s
# 374037: done 353 games, mean reward -6.850, speed 66.76 f/s
# 375667: done 354 games, mean reward -6.430, speed 66.45 f/s
# 377616: done 355 games, mean reward -6.080, speed 66.33 f/s
# 379253: done 356 games, mean reward -5.680, speed 66.42 f/s
# 381076: done 357 games, mean reward -5.280, speed 66.58 f/s
# 382773: done 358 games, mean reward -4.880, speed 66.60 f/s
# 384564: done 359 games, mean reward -4.490, speed 66.76 f/s
# 386367: done 360 games, mean reward -4.110, speed 66.57 f/s
# 388003: done 361 games, mean reward -3.720, speed 66.57 f/s
# 389732: done 362 games, mean reward -3.350, speed 66.63 f/s
# 391443: done 363 games, mean reward -2.980, speed 66.68 f/s
# 393113: done 364 games, mean reward -2.590, speed 66.51 f/s
# 394787: done 365 games, mean reward -2.220, speed 66.53 f/s
# 396486: done 366 games, mean reward -1.830, speed 66.34 f/s
# 398184: done 367 games, mean reward -1.520, speed 66.13 f/s
# 399846: done 368 games, mean reward -1.180, speed 66.16 f/s
# 401484: done 369 games, mean reward -0.800, speed 65.89 f/s
# 403168: done 370 games, mean reward -0.450, speed 66.00 f/s
# 404837: done 371 games, mean reward -0.040, speed 66.00 f/s
# 406526: done 372 games, mean reward 0.360, speed 66.00 f/s
# 408961: done 373 games, mean reward 0.550, speed 66.28 f/s
# 410621: done 374 games, mean reward 0.930, speed 66.29 f/s
# 412260: done 375 games, mean reward 1.350, speed 66.32 f/s
# 413988: done 376 games, mean reward 1.760, speed 66.32 f/s
# 415750: done 377 games, mean reward 2.160, speed 66.24 f/s
# 417601: done 378 games, mean reward 2.460, speed 66.31 f/s
# 419524: done 379 games, mean reward 2.840, speed 66.28 f/s
# 421211: done 380 games, mean reward 3.250, speed 66.32 f/s
# 422965: done 381 games, mean reward 3.590, speed 66.42 f/s
# 424641: done 382 games, mean reward 3.980, speed 66.36 f/s
# 426401: done 383 games, mean reward 4.300, speed 66.32 f/s
# 428660: done 384 games, mean reward 4.570, speed 66.49 f/s
# 430349: done 385 games, mean reward 4.970, speed 66.46 f/s
# 432095: done 386 games, mean reward 5.360, speed 66.42 f/s
# 433985: done 387 games, mean reward 5.730, speed 66.48 f/s
# 436047: done 388 games, mean reward 6.080, speed 66.51 f/s
# 437688: done 389 games, mean reward 6.500, speed 66.45 f/s
# 439329: done 390 games, mean reward 6.910, speed 66.42 f/s
# 440206: done 391 games, mean reward 6.900, speed 66.48 f/s
# 442274: done 392 games, mean reward 7.220, speed 66.54 f/s
# 443910: done 393 games, mean reward 7.550, speed 66.36 f/s
# 445668: done 394 games, mean reward 7.930, speed 65.95 f/s
# 447641: done 395 games, mean reward 8.290, speed 66.21 f/s
# 449394: done 396 games, mean reward 8.590, speed 66.08 f/s
# 451148: done 397 games, mean reward 8.990, speed 66.31 f/s
# 452846: done 398 games, mean reward 9.400, speed 66.39 f/s
# 454594: done 399 games, mean reward 9.800, speed 66.36 f/s
# 456610: done 400 games, mean reward 10.170, speed 66.23 f/s
# 458279: done 401 games, mean reward 10.560, speed 66.29 f/s
# 459972: done 402 games, mean reward 10.960, speed 66.29 f/s
# 462036: done 403 games, mean reward 11.300, speed 66.25 f/s
# 463677: done 404 games, mean reward 11.570, speed 66.17 f/s
# 465425: done 405 games, mean reward 11.850, speed 65.99 f/s
# 467247: done 406 games, mean reward 12.210, speed 66.14 f/s
# 469000: done 407 games, mean reward 12.480, speed 66.07 f/s
# 470636: done 408 games, mean reward 12.880, speed 66.15 f/s
# 472305: done 409 games, mean reward 13.110, speed 66.07 f/s
# 473946: done 410 games, mean reward 13.490, speed 66.10 f/s
# 475586: done 411 games, mean reward 13.900, speed 66.22 f/s
# 477223: done 412 games, mean reward 14.250, speed 65.74 f/s
# 478922: done 413 games, mean reward 14.630, speed 66.02 f/s
# 480556: done 414 games, mean reward 15.010, speed 66.09 f/s
# 482274: done 415 games, mean reward 15.290, speed 66.27 f/s
# 483913: done 416 games, mean reward 15.600, speed 65.93 f/s
# 485678: done 417 games, mean reward 15.840, speed 66.15 f/s
# 487343: done 418 games, mean reward 16.080, speed 66.31 f/s
# 488979: done 419 games, mean reward 16.410, speed 66.38 f/s
# 490774: done 420 games, mean reward 16.650, speed 66.39 f/s
# 492496: done 421 games, mean reward 16.830, speed 66.42 f/s
# 494156: done 422 games, mean reward 17.070, speed 66.41 f/s
# 495797: done 423 games, mean reward 17.240, speed 66.31 f/s
# 497748: done 424 games, mean reward 17.370, speed 66.19 f/s
# 499382: done 425 games, mean reward 17.740, speed 66.28 f/s
# 501303: done 426 games, mean reward 17.980, speed 66.14 f/s
# 502940: done 427 games, mean reward 18.200, speed 66.16 f/s
# Solved in 502940 frames!
